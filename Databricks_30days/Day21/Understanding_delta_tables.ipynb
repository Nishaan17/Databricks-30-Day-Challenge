# %%
# %sql
-- create table employeed (id int,name string, salary int);

# %%
# %sql
Describe detail employeed;

# %%
# %sql
-- insert into employeed(id,name,salary) values (1,'John',50000),(2,'Jane',60000),(3,'Bob',70000);

# %%
# %sql
describe history employeed;

# %%
# %sql
select * from employeed;

# %%
# %sql
insert into employeed(id,name,salary) values (4,'Mary',80000),(5,'Alice',90000),(6,'Tom',100000),(7,'Bob',110000);

# %%
# %sql
update employeed set salary = 100000 where id in (1,2,4,6);

# %%
# %sql
describe history employeed;

# %%
# %sql
select * from employeed;

# %%
# %sql
select * from employeed@v2;

# %%
# %sql
delete from  employeed;

# %%
# %sql
select * from employeed;

# %%
# %sql
describe history employeed;

# %%
# %sql
RESTORE employeed TO VERSION AS OF 4;

# %%
# %sql
select * from employeed;

# %%
# %sql
describe history employeed;

# %%
# %sql
describe detail employeed;

# %%
# %sql
OPTIMIZE employeed
ZORDER by id;

# %%
# %sql
DESCRIBE HISTORY employeed;

# %%
# %sql
VACUUM employeed;

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled=false;

# %%
# %sql
VACUUM employeed;
