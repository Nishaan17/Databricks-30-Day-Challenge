# %%
df = spark.read.table("databricks_30days.default.day1")
display(df)

# %%
display(range(10))

# %%
spark.range(20)

# %%
display(spark.range(20))

# %%
df = spark.range(10)
df.show()

# %%
df.printSchema()
