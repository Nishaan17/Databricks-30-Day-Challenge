# %%
# %sql
DESCRIBE HISTORY day4_employee;

# %%
# %sql
SELECT * FROM day4_employee VERSION AS OF 0;

SELECT * FROM day4_employee VERSION AS OF 1;

SELECT * FROM day4_employee VERSION AS OF 2;

SELECT * FROM day4_employee VERSION AS OF 3;

# %%
# %sql
UPDATE day4_employee
SET salary = 110000
WHERE id = 1;

# %%
# %sql
DELETE FROM day4_employee
WHERE id = 5;

# %%
# %sql
DESCRIBE HISTORY day4_employee;

# %%
# %sql
SELECT * FROM day4_employee VERSION AS OF 3;

# %% [markdown]
# UPDATE
# ↓
#
# New Version Created
# ↓
#
# New Parquet File Created
# ↓
#
# _delta_log Updated
# ↓
#
# Old Version Preserved
# ↓
#
# Time Travel Possible
