# %% [markdown]
# # dbutils.fs

# %%
files = dbutils.fs.ls('abfss://raw@datalakenishaan.dfs.core.windows.net/')
display(files)

# %% [markdown]
# # dbutils.widgets

# %%
dbutils.widgets.text('p_name','Nishaan')
dbutils.widgets.text('p_id','1')
dbutils.widgets.text('p_age','23')

# %%
name=dbutils.widgets.get('p_name')
id=dbutils.widgets.get('p_id')
age=dbutils.widgets.get('p_age')
print(name)
print(id)
print(age)

# %% [markdown]
# # dbutils.secret

# %% [markdown]
# Step 1:
# - -  Create a vault in azure portal
# - - Before that give IAM role
# - -   Create a secret in vault
# - -   After this copy the databricks url(end as .net) and past it in google and add #secrets/createScope
# - -   After this click enter
# - -   There enter the vault url(DNS) and resource id

# %%
# Just an demo this, now wotking
# dbutils.secrets.get(scope='formula1-scope',key='app-secret')

# %% [markdown]
# # Reading data from file

# %%
# %py
df_data = spark.read.format('csv')\
            .option('header',True)\
            .option('inferSchema',True)\
            .load('abfss://raw@datalakenishaan.dfs.core.windows.net/')

# %%
df_data.display()

# %% [markdown]
# # Pyspark Transformations

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_data.withColumn('JOB_ID',split(col('JOB_ID'),'_')).display()

# %%
df_data.withColumn('Name',lit(name)).display()
