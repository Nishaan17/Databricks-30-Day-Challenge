# %%
# %sql
select * from sales.exttable;

# %%
# %sql
describe history sales.exttable;

# %%
# %sql
INSERT into sales.exttable values(99,'apple',10),(98,'banana',20),(97,'cat',30),(96,'dolphin',40);

# %%
# %sql
delete from sales.exttable where id=99;

# %%
# %sql
Create database test;

# %%
# %sql
CReate table If not exists test.sampe_delta_test(
    id int,
    name string,
    mark int
) using Delta
location 'abfss://destination@datalakenishaan.dfs.core.windows.net/test/sampe_delta_test';

# %%
# %sql
Insert into test.sampe_delta_test(id,name,mark) values (1,'sam',10),(2,'peter',20),(3,'john',30),(4,'jack',40);

# %%
# %sql
INSERT into test.sampe_delta_test(id,name,mark) values (5,'nishaan',100),(6,'nivetha',200),(7,'vicky',300),(8,'hema',400);

# %%
# %sql
update test.sampe_delta_test set mark=500 where id=8;

# %%
# %sql
DESCRIBE HISTORY test.sampe_delta_test;

# %%
# %sql
select * from test.sampe_delta_test;

# %%
# %sql
delete from test.sampe_delta_test where id=6;

# %%
# %sql
select * from test.sampe_delta_test;

# %%
# %sql
DESCRIBE HISTORY test.sampe_delta_test;

# %%
# %sql
RESTORE TABLE test.sampe_delta_test TO VERSION AS OF 5;

# %%
# %sql
select * from test.sampe_delta_test;

# %%
# %sql
RESTORE TABLE test.sampe_delta_test TO VERSION AS OF 4;

# %%
# %sql
select * from test.sampe_delta_test;

# %%
# %sql
DESCRIBE HISTORY test.sampe_delta_test;
