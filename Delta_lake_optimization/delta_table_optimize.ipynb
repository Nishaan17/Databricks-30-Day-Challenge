# %% [markdown]
# ## Optimize

# %%
# %sql
select * from test.sampe_delta_test;

# %%
# %sql
OPTIMIZE test.sampe_delta_test;

# %%
# %sql
select * from test.sampe_delta_test;

# %% [markdown]
# ## Z Order by

# %%
# %sql
OPTIMIZE test.sampe_delta_test ZORDER BY (id);

# %%
# %sql
select * from test.sampe_delta_test;
