# %% [markdown]
# # DLT Pipeline

# %% [markdown]
# ## Streaming table

# %%
import dlt
from pyspark.sql.functions import *

# %%
@dlt.table()

def DimProducts_stage():
    df=spark.readStream.table('databricks_cat_1234.silver.silver_products')
    return df

# %% [markdown]
# ## Streaming view

# %%
dlt.view()

def DimProducts_view():
    df=spark.readStream.table('Live.DimProducts_stage')
    return df

# %% [markdown]
# ## Dim Products
